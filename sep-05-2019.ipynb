# %% [markdown]
# ### markdown introduction

# %% [markdown]
# # heading1
# ## heading2
# ### heading3
# #### heading4
# ##### heading5
# ###### heading6

# %% [markdown]
# **bold**

# %% [markdown]
# *italic*<br></br>
# <strike>striking text</strike><br></br>
# `highlightingtext`

# %% [markdown]
# <img src= "http://localhost:8888/kernelspecs/python3/logo-64x64.png" width="100px" height="100px" >

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# %%HTML
# <iframe width="1280" height="720" src="https://www.youtube.com/embed/_uQrJ0TkZlc" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# * python
# * java
# * R programming
# * scripting languages
#   - html
#   - xml

# %% [markdown]
# # Python Programming

# %%
print("Hello World")
print("apssdc")
# Out:
# Hello World
# apssdc

# %%
print(1)
print("a")
# Out:
# 1
# a

# %% [markdown]
# # Operators

# %% [markdown]
# * arithematic operators
# * relational
# * assignment
# * logical
# * bitwise
# * identity
# * membership

# %% [markdown]
# # Arithematic Operators

# %%
print(29+29)
print(29-19)
print(17*60)
print(20/7)
# Out:
# 58
# 10
# 1020
# 2.857142857142857

# %%
type(20/7)
# Out:
# float

# %%
20//7
# Out:
# 2

# %%
print(20%7)
# Out:
# 6

# %%
print(5 ** 5)
# Out:
# 3125

# %%
print(pow(5,5))
# Out:
# 3125

# %% [markdown]
# # Logical Operators

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
False and False
# Out:
# False

# %%
False or False
# Out:
# False

# %%
not False
# Out:
# True

# %%
not True
# Out:
# False

# %% [markdown]
# ## Relational Operators

# %%
2 == 3
# Out:
# False

# %%
2!=3
# Out:
# True

# %%
2<10
# Out:
# True

# %%
10>90
# Out:
# False

# %% [markdown]
# ## Assignment Operators

# %%
a=10

# %%
type(a)
# Out:
# int

# %%
b='c'

# %%
type(b)
# Out:
# str

# %%
type("Nineesha")
# Out:
# str

# %%
a=b=c=20

# %%
a,b,c=20,30,40

# %%
a,b,c
# Out:
# (20, 30, 40)

# %%
print(a,b,c)
# Out:
# 20 30 40

# %%
a
b
c
# Out:
# 40

# %%
a,b=b,a

# %%
a,b
# Out:
# (30, 20)

# %%
a,b=b,c=c,a=a,c

# %%
a,b,c
# Out:
# (30, 40, 40)

# %%
a=1
a
# Out:
# 1

# %%
a++  # it is not supported in python
a
# Out:
#   File "<ipython-input-46-c4f01afdd600>", line 1
#     a++  ##it is not supported in python
#                                         ^
# SyntaxError: invalid syntax

# %%
a=a+1
a
# Out:
# 2

# %%
a+=1
a
# Out:
# 3

# %% [markdown]
# # Bitwise Operators

# %%
4&7
# Out:
# 4

# %%
7 | 4
# Out:
# 7

# %%
8 << 2
# Out:
# 32

# %%
8 >> 2
# Out:
# 2

# %% [markdown]
# # Identity Operators

# %%
2 is not 3
# Out:
# True

# %%
2 is 2
# Out:
# True

# %% [markdown]
# # Membership Operators

# %%
"ap" in "apssdc"
# Out:
# True

# %%
"ni" not in "nineesha"
# Out:
# False

# %%
"Ni" not in "nineesha"
# Out:
# True
